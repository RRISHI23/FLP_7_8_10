# %%
import re
from collections import defaultdict
from functools import reduce
from datetime import datetime, timedelta  


# Example log file (you can replace this with your actual log file)
log_file_path = "C:\\Users\\Rrish\\Downloads\\log.txt"  # Replace with the actual path to your file
try:
    with open(log_file_path, 'r') as file:
        file_content = file.read()
        # Parse log entries into tuples (timestamp, log_level, message)
        log_entries = [line.strip().split(" - ") for line in file_content.splitlines()]
        parsed_log = [(entry[0], entry[1], entry[2]) for entry in log_entries if len(entry) == 3]

except FileNotFoundError:
    print(f"File '{log_file_path}' not found.")

# Extract timestamps
timestamps = [entry[0] for entry in parsed_log]

# Extract log levels
log_levels = [entry[1] for entry in parsed_log]

# Extract message
log_messages = [entry[2] for entry in parsed_log]

# Calculate log level counts
log_level_counts = {
    "INFO": log_levels.count("INFO"),
    "ERROR": log_levels.count("ERROR"),
    "WARNING": log_levels.count("WARNING"),
    "DEBUG": log_levels.count("DEBUG"),
}

# Extract usernames
username_pattern = r"User logged in: (\w+)|User logged out: (\w+)"
usernames = []
for message in log_messages:
    match = re.search(username_pattern, message)
    if match:
        username = match.group(1) or match.group(2)
        usernames.append(username)

# Count user logins
user_logins = {}
for username in set(usernames):
    user_logins[username] = usernames.count(username)

# Extract file names
file_pattern = r"File uploaded: (\w+\.\w+)"
file_names = []
for message in log_messages:
    match = re.search(file_pattern, message)
    if match:
        file_name = match.group(1)
        file_names.append(file_name)

# Extract failed file uploads
failed_upload_pattern = r"File not found: (\w+\.\w+)"
failed_uploads = [
    match.group(1)
    for message in log_messages
    for match in [re.search(failed_upload_pattern, message)]
    if match
]

# Extract user reminders and count total failures
reminders = map(lambda line: f"Reminder to user: Please upload the file again. Log entry: {line.strip()}",
                failed_uploads)
total_failures = reduce(lambda count, _: count + 1, failed_uploads, 0)

# Extract low disk space warnings
low_disk_space_pattern = r"Disk space (low|critically low)"
low_disk_space_warnings = list(filter(lambda message: re.search(low_disk_space_pattern, message), log_messages))


# Extract invalid authentication token errors
invalid_auth_token_pattern = r"Invalid authentication token"
invalid_auth_token_errors = [
    message
    for message in log_messages
    if re.search(invalid_auth_token_pattern, message)
]

# Extract internal server errors
internal_server_error_pattern = r"Internal server error: database connection failed"
internal_server_errors = list(filter(lambda message: re.search(internal_server_error_pattern, message), log_messages))

# Extract connection reset by peer errors
connection_reset_pattern = r"Connection reset by peer"
connection_reset_errors = list(filter(lambda message: re.search(connection_reset_pattern, message), log_messages))

# Calculate error handling time (time between error and debug)
error_debug_times = []
error_timestamps = [timestamps[i] for i, level in enumerate(log_levels) if level == "ERROR"]
debug_timestamps = [timestamps[i] for i, level in enumerate(log_levels) if level == "DEBUG"]

for error_time in error_timestamps:
    try:
        debug_time = next(time for time in debug_timestamps if time > error_time)
        error_debug_times.append((error_time, debug_time))
    except StopIteration:
        pass


# Convert timestamps to datetime objects for calculation
error_debug_times_datetime = [(datetime.strptime(error_time, "%Y-%m-%d %H:%M:%S"), datetime.strptime(debug_time, "%Y-%m-%d %H:%M:%S")) for error_time, debug_time in error_debug_times]



# Print statistics
print("Log Level Counts:")
for level, count in log_level_counts.items():
    print(f"{level}: {count}")

# Print reminders and total failures
#for reminder in reminders:
#    print(reminder)
print(f"Total number of files failed to upload: {total_failures}")

# Example to organize data by specific user - login time, low disk space warning, authentication error.
user_data = defaultdict(lambda: {"logins": [], "disk_space_warnings": [], "invalid_auth_tokens": [], "failed_uploads": []})
for username, timestamp, message in zip(usernames, timestamps, log_messages):
    user_data[username]["logins"].append(timestamp)

    low_disk_space_pattern = r"Disk space (low|critically low)"
    if re.search(low_disk_space_pattern, message):
        user_data[username]["disk_space_warnings"].append(message)

    invalid_auth_token_pattern = r"Invalid authentication token"
    if re.search(invalid_auth_token_pattern, message):
        user_data[username]["invalid_auth_tokens"].append(message)

    failed_upload_match = re.search(failed_upload_pattern, message)
    if failed_upload_match:
        user_data[username]["failed_uploads"].append(failed_upload_match.group(1))

# Internal Server Errors 
user_internal_server_errors = defaultdict(int)
for username, message in zip(usernames, log_messages):
  if re.search(internal_server_error_pattern, message):
    user_internal_server_errors[username] += 1
      
# Connection Reset by Peer Counts with Username Association
user_connection_reset_counts = defaultdict(int)
for username, message in zip(usernames, log_messages):
  if re.search(connection_reset_pattern, message):
    user_connection_reset_counts[username] += 1


# Example to produce output from data organised for specific user
print("\nUser Data:")
for username, user_info in user_data.items():
    print(f"\nUsername: {username}")
    print("Login timestamps:")
    print("\n".join(user_info["logins"]))
    print("Login frequency: ",user_logins.get(username))
    if user_info["disk_space_warnings"]:
        print(f"  Disk space warnings: {','.join(user_info['disk_space_warnings'])}")
        print(f"  Please increase storage space for this user.")
    if user_info["invalid_auth_tokens"]:
        print(f"  Invalid authentication token errors: {','.join(user_info['invalid_auth_tokens'])}")
        print(f"  This user may have experienced difficulties logging in. This could indicate a security breach.")
    if user_info['failed_uploads']:
        print(f"  Failed Uploads: {user_info['failed_uploads']}")
        for file in user_info['failed_uploads']:
            print(f"  Reminder to user: Please upload the file '{file}' again.")
    if user_internal_server_errors[username]:
        print(f"  Internal Server Errors: {user_internal_server_errors[username]}")
        print("  Database connection failed: database service is down")
    if user_connection_reset_counts[username]:
        print(f"  Connection Reset by Peer: {user_connection_reset_counts[username]}")
        print("  Potential network connectivity issues or server instability")


# Usernames with Internal Server Errors (calculated once)
users_with_internal_errors = [username for username, message in zip(usernames, log_messages) if re.search(internal_server_error_pattern, message)]

# List of Usernames with Internal Server Errors 
if users_with_internal_errors:
  print("\nUsernames with Internal Server Errors:")
  for username in users_with_internal_errors:
    print(username)

# Usernames with Connection Reset (calculated once)
users_with_connection_reset = [username for username, message in zip(usernames, log_messages) if re.search(connection_reset_pattern, message)]

# Print Usernames with Errors (if any)
if users_with_connection_reset:
  print("\nUsernames with Connection Reset by Peer:")
  for username in users_with_connection_reset:
    print(username)



      
# Calculate total time difference and average error-debug time (handle potential division by zero)
total_time_delta = timedelta(seconds=0)  # Initialize total time difference as 0
if error_debug_times_datetime:
  for error_time, debug_time in error_debug_times_datetime:
    time_delta = debug_time - error_time
    total_time_delta += time_delta
  average_error_debug_time = total_time_delta / len(error_debug_times_datetime)
  print(f"\nAverage Error-Debug Time: {average_error_debug_time}")
# Out:
# Log Level Counts:
# INFO: 500
# ERROR: 214
# WARNING: 143
# DEBUG: 143
# Total number of files failed to upload: 71
#
# User Data:
#
# Username: username123
# Login timestamps:
# 2024-02-29 08:15:23
# 2024-02-29 08:16:45
# Login frequency:  2
#
# Username: user456
# Login timestamps:
# 2024-02-29 08:17:30
# 2024-02-29 08:18:02
# Login frequency:  2
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user789
# Login timestamps:
# 2024-02-29 08:19:55
# 2024-02-29 08:20:10
# Login frequency:  2
#
# Username: user101
# Login timestamps:
# 2024-02-29 08:21:30
# 2024-02-29 08:22:15
# 2024-02-29 11:13:15
# 2024-02-29 11:13:30
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user202
# Login timestamps:
# 2024-02-29 08:23:05
# 2024-02-29 08:24:20
# 2024-02-29 11:14:45
# 2024-02-29 11:15:30
# Login frequency:  4
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#   Failed Uploads: ['missing_file.txt']
#   Reminder to user: Please upload the file 'missing_file.txt' again.
#
# Username: user303
# Login timestamps:
# 2024-02-29 08:25:15
# 2024-02-29 08:25:45
# 2024-02-29 11:16:00
# 2024-02-29 11:17:20
# Login frequency:  4
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user404
# Login timestamps:
# 2024-02-29 08:26:30
# 2024-02-29 08:27:10
# 2024-02-29 11:18:05
# 2024-02-29 11:19:10
# Login frequency:  4
#
# Username: user505
# Login timestamps:
# 2024-02-29 08:28:00
# 2024-02-29 08:29:20
# 2024-02-29 11:20:25
# 2024-02-29 11:20:40
# Login frequency:  4
#   Disk space warnings: Disk space critically low
#   Please increase storage space for this user.
#
# Username: user606
# Login timestamps:
# 2024-02-29 08:30:05
# 2024-02-29 08:31:10
# 2024-02-29 11:21:55
# 2024-02-29 11:22:45
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#   Connection Reset by Peer: 1
#   Potential network connectivity issues or server instability
#
# Username: user707
# Login timestamps:
# 2024-02-29 08:32:25
# 2024-02-29 08:32:40
# 2024-02-29 11:23:30
# 2024-02-29 11:24:20
# Login frequency:  4
#   Failed Uploads: ['data.csv']
#   Reminder to user: Please upload the file 'data.csv' again.
#
# Username: user808
# Login timestamps:
# 2024-02-29 08:33:55
# 2024-02-29 08:34:45
# 2024-02-29 11:25:15
# 2024-02-29 11:25:45
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user909
# Login timestamps:
# 2024-02-29 08:35:30
# 2024-02-29 08:36:20
# 2024-02-29 11:26:30
# 2024-02-29 11:27:10
# Login frequency:  4
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#   Failed Uploads: ['config.ini']
#   Reminder to user: Please upload the file 'config.ini' again.
#
# Username: user010
# Login timestamps:
# 2024-02-29 08:37:15
# 2024-02-29 08:37:30
# 2024-02-29 11:28:00
# 2024-02-29 11:29:20
# Login frequency:  4
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user111
# Login timestamps:
# 2024-02-29 08:38:45
# 2024-02-29 08:39:30
# 2024-02-29 11:30:05
# 2024-02-29 11:31:10
# Login frequency:  4
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#
# Username: user212
# Login timestamps:
# 2024-02-29 08:40:00
# 2024-02-29 08:41:20
# 2024-02-29 11:32:25
# 2024-02-29 11:32:40
# Login frequency:  4
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user313
# Login timestamps:
# 2024-02-29 08:42:05
# 2024-02-29 08:43:10
# 2024-02-29 11:33:55
# 2024-02-29 11:34:45
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user414
# Login timestamps:
# 2024-02-29 08:44:25
# 2024-02-29 08:44:40
# 2024-02-29 11:35:30
# 2024-02-29 11:36:20
# Login frequency:  4
#   Failed Uploads: ['presentation.pptx']
#   Reminder to user: Please upload the file 'presentation.pptx' again.
#
# Username: user515
# Login timestamps:
# 2024-02-29 08:45:55
# 2024-02-29 08:46:45
# 2024-02-29 11:37:15
# 2024-02-29 11:37:30
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user616
# Login timestamps:
# 2024-02-29 08:47:30
# 2024-02-29 08:48:20
# 2024-02-29 11:38:45
# 2024-02-29 11:39:30
# Login frequency:  4
#   Failed Uploads: ['script.py']
#   Reminder to user: Please upload the file 'script.py' again.
#
# Username: user717
# Login timestamps:
# 2024-02-29 08:49:15
# 2024-02-29 08:49:45
# 2024-02-29 11:40:00
# 2024-02-29 11:41:20
# Login frequency:  4
#   Disk space warnings: Disk space critically low
#   Please increase storage space for this user.
#
# Username: user818
# Login timestamps:
# 2024-02-29 08:50:30
# 2024-02-29 08:51:10
# 2024-02-29 11:42:05
# 2024-02-29 11:43:10
# Login frequency:  4
#   Connection Reset by Peer: 1
#   Potential network connectivity issues or server instability
#
# Username: user919
# Login timestamps:
# 2024-02-29 08:52:00
# 2024-02-29 08:53:20
# 2024-02-29 11:44:25
# 2024-02-29 11:44:40
# Login frequency:  4
#   Disk space warnings: Disk space critically low
#   Please increase storage space for this user.
#
# Username: user020
# Login timestamps:
# 2024-02-29 08:54:05
# 2024-02-29 08:55:10
# 2024-02-29 11:45:55
# 2024-02-29 11:46:45
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#   Connection Reset by Peer: 1
#   Potential network connectivity issues or server instability
#
# Username: user121
# Login timestamps:
# 2024-02-29 08:56:25
# 2024-02-29 08:56:40
# 2024-02-29 11:47:30
# 2024-02-29 11:48:20
# Login frequency:  4
#   Failed Uploads: ['data.csv']
#   Reminder to user: Please upload the file 'data.csv' again.
#
# Username: user222
# Login timestamps:
# 2024-02-29 08:57:55
# 2024-02-29 08:58:45
# 2024-02-29 11:49:15
# 2024-02-29 11:49:45
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user323
# Login timestamps:
# 2024-02-29 08:59:30
# 2024-02-29 09:00:20
# 2024-02-29 11:50:30
# 2024-02-29 11:51:10
# Login frequency:  4
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#   Failed Uploads: ['settings.xml']
#   Reminder to user: Please upload the file 'settings.xml' again.
#
# Username: user424
# Login timestamps:
# 2024-02-29 09:01:15
# 2024-02-29 09:01:45
# 2024-02-29 11:52:00
# 2024-02-29 11:53:20
# Login frequency:  4
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user525
# Login timestamps:
# 2024-02-29 09:02:30
# 2024-02-29 09:03:10
# 2024-02-29 11:54:05
# 2024-02-29 11:55:10
# Login frequency:  4
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#
# Username: user626
# Login timestamps:
# 2024-02-29 09:04:00
# 2024-02-29 09:05:20
# 2024-02-29 11:56:25
# 2024-02-29 11:56:40
# Login frequency:  4
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user727
# Login timestamps:
# 2024-02-29 09:06:05
# 2024-02-29 09:07:10
# 2024-02-29 11:57:55
# 2024-02-29 11:58:45
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user828
# Login timestamps:
# 2024-02-29 09:08:25
# 2024-02-29 09:08:40
# 2024-02-29 11:59:30
# 2024-02-29 12:00:20
# Login frequency:  4
#   Failed Uploads: ['image.png']
#   Reminder to user: Please upload the file 'image.png' again.
#
# Username: user929
# Login timestamps:
# 2024-02-29 09:09:55
# 2024-02-29 09:10:45
# 2024-02-29 12:01:15
# 2024-02-29 12:01:45
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user030
# Login timestamps:
# 2024-02-29 09:11:30
# 2024-02-29 09:12:20
# 2024-02-29 12:02:30
# 2024-02-29 12:03:10
# Login frequency:  4
#   Failed Uploads: ['report.docx']
#   Reminder to user: Please upload the file 'report.docx' again.
#
# Username: user131
# Login timestamps:
# 2024-02-29 09:13:15
# 2024-02-29 09:13:30
# 2024-02-29 12:04:00
# 2024-02-29 12:05:20
# Login frequency:  4
#   Disk space warnings: Disk space critically low
#   Please increase storage space for this user.
#
# Username: user232
# Login timestamps:
# 2024-02-29 09:14:45
# 2024-02-29 09:15:30
# 2024-02-29 12:06:05
# 2024-02-29 12:07:10
# Login frequency:  4
#   Connection Reset by Peer: 1
#   Potential network connectivity issues or server instability
#
# Username: user333
# Login timestamps:
# 2024-02-29 09:16:00
# 2024-02-29 09:17:20
# 2024-02-29 12:08:25
# 2024-02-29 12:08:40
# Login frequency:  4
#   Disk space warnings: Disk space critically low
#   Please increase storage space for this user.
#
# Username: user434
# Login timestamps:
# 2024-02-29 09:18:05
# 2024-02-29 09:19:10
# 2024-02-29 12:09:55
# 2024-02-29 12:10:45
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#   Connection Reset by Peer: 1
#   Potential network connectivity issues or server instability
#
# Username: user535
# Login timestamps:
# 2024-02-29 09:20:25
# 2024-02-29 09:20:40
# 2024-02-29 12:11:30
# 2024-02-29 12:12:20
# Login frequency:  4
#   Failed Uploads: ['report.docx']
#   Reminder to user: Please upload the file 'report.docx' again.
#
# Username: user636
# Login timestamps:
# 2024-02-29 09:21:55
# 2024-02-29 09:22:45
# 2024-02-29 12:13:15
# 2024-02-29 12:13:30
# Login frequency:  4
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user737
# Login timestamps:
# 2024-02-29 09:23:30
# 2024-02-29 09:24:20
# 2024-02-29 12:14:45
# 2024-02-29 12:15:30
# Login frequency:  4
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#   Failed Uploads: ['script.py']
#   Reminder to user: Please upload the file 'script.py' again.
#
# Username: user838
# Login timestamps:
# 2024-02-29 09:25:15
# 2024-02-29 09:25:45
# 2024-02-29 12:16:00
# 2024-02-29 12:17:20
# Login frequency:  4
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user939
# Login timestamps:
# 2024-02-29 09:26:30
# 2024-02-29 09:27:10
# 2024-02-29 12:18:05
# 2024-02-29 12:19:10
# Login frequency:  4
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#
# Username: user040
# Login timestamps:
# 2024-02-29 09:28:00
# 2024-02-29 09:29:20
# 2024-02-29 12:20:25
# Login frequency:  3
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user141
# Login timestamps:
# 2024-02-29 09:30:05
# 2024-02-29 09:31:10
# Login frequency:  2
#
# Username: user242
# Login timestamps:
# 2024-02-29 09:32:25
# 2024-02-29 09:32:40
# Login frequency:  2
#
# Username: user343
# Login timestamps:
# 2024-02-29 09:33:55
# 2024-02-29 09:34:45
# Login frequency:  2
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user444
# Login timestamps:
# 2024-02-29 09:35:30
# 2024-02-29 09:36:20
# Login frequency:  2
#   Failed Uploads: ['presentation.pptx']
#   Reminder to user: Please upload the file 'presentation.pptx' again.
#
# Username: user545
# Login timestamps:
# 2024-02-29 09:37:15
# 2024-02-29 09:37:30
# Login frequency:  2
#
# Username: user646
# Login timestamps:
# 2024-02-29 09:38:45
# 2024-02-29 09:39:30
# Login frequency:  2
#
# Username: user747
# Login timestamps:
# 2024-02-29 09:40:00
# 2024-02-29 09:41:20
# Login frequency:  2
#   Disk space warnings: Disk space critically low
#   Please increase storage space for this user.
#
# Username: user848
# Login timestamps:
# 2024-02-29 09:42:05
# 2024-02-29 09:43:10
# Login frequency:  2
#   Connection Reset by Peer: 1
#   Potential network connectivity issues or server instability
#
# Username: user949
# Login timestamps:
# 2024-02-29 09:44:25
# 2024-02-29 09:44:40
# Login frequency:  2
#
# Username: user050
# Login timestamps:
# 2024-02-29 09:45:55
# 2024-02-29 09:46:45
# Login frequency:  2
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user151
# Login timestamps:
# 2024-02-29 09:47:30
# 2024-02-29 09:48:20
# Login frequency:  2
#   Failed Uploads: ['data.csv']
#   Reminder to user: Please upload the file 'data.csv' again.
#
# Username: user252
# Login timestamps:
# 2024-02-29 09:49:15
# 2024-02-29 09:49:45
# Login frequency:  2
#
# Username: user353
# Login timestamps:
# 2024-02-29 09:50:30
# 2024-02-29 09:51:10
# Login frequency:  2
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#
# Username: user454
# Login timestamps:
# 2024-02-29 09:52:00
# 2024-02-29 09:53:20
# Login frequency:  2
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user555
# Login timestamps:
# 2024-02-29 09:54:05
# 2024-02-29 09:55:10
# Login frequency:  2
#
# Username: user656
# Login timestamps:
# 2024-02-29 09:56:25
# 2024-02-29 09:56:40
# Login frequency:  2
#
# Username: user757
# Login timestamps:
# 2024-02-29 09:57:55
# 2024-02-29 09:58:45
# Login frequency:  2
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user858
# Login timestamps:
# 2024-02-29 09:59:30
# 2024-02-29 10:00:20
# Login frequency:  2
#   Failed Uploads: ['image.png']
#   Reminder to user: Please upload the file 'image.png' again.
#
# Username: user959
# Login timestamps:
# 2024-02-29 10:01:15
# 2024-02-29 10:01:45
# Login frequency:  2
#
# Username: user060
# Login timestamps:
# 2024-02-29 10:02:30
# 2024-02-29 10:03:10
# Login frequency:  2
#
# Username: user161
# Login timestamps:
# 2024-02-29 10:04:00
# 2024-02-29 10:05:20
# Login frequency:  2
#   Disk space warnings: Disk space critically low
#   Please increase storage space for this user.
#
# Username: user262
# Login timestamps:
# 2024-02-29 10:06:05
# 2024-02-29 10:07:10
# Login frequency:  2
#   Connection Reset by Peer: 1
#   Potential network connectivity issues or server instability
#
# Username: user363
# Login timestamps:
# 2024-02-29 10:08:25
# 2024-02-29 10:08:40
# Login frequency:  2
#
# Username: user464
# Login timestamps:
# 2024-02-29 10:09:55
# 2024-02-29 10:10:45
# Login frequency:  2
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user565
# Login timestamps:
# 2024-02-29 10:11:30
# 2024-02-29 10:12:20
# Login frequency:  2
#   Failed Uploads: ['report.docx']
#   Reminder to user: Please upload the file 'report.docx' again.
#
# Username: user666
# Login timestamps:
# 2024-02-29 10:13:15
# 2024-02-29 10:13:30
# Login frequency:  2
#
# Username: user767
# Login timestamps:
# 2024-02-29 10:14:45
# 2024-02-29 10:15:30
# Login frequency:  2
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#
# Username: user868
# Login timestamps:
# 2024-02-29 10:16:00
# 2024-02-29 10:17:20
# Login frequency:  2
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user969
# Login timestamps:
# 2024-02-29 10:18:05
# 2024-02-29 10:19:10
# Login frequency:  2
#
# Username: user070
# Login timestamps:
# 2024-02-29 10:20:25
# 2024-02-29 10:20:40
# Login frequency:  2
#
# Username: user171
# Login timestamps:
# 2024-02-29 10:21:55
# 2024-02-29 10:22:45
# Login frequency:  2
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user272
# Login timestamps:
# 2024-02-29 10:23:30
# 2024-02-29 10:24:20
# Login frequency:  2
#   Failed Uploads: ['data.csv']
#   Reminder to user: Please upload the file 'data.csv' again.
#
# Username: user373
# Login timestamps:
# 2024-02-29 10:25:15
# 2024-02-29 10:25:45
# Login frequency:  2
#
# Username: user474
# Login timestamps:
# 2024-02-29 10:26:30
# 2024-02-29 10:27:10
# Login frequency:  2
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#
# Username: user575
# Login timestamps:
# 2024-02-29 10:28:00
# 2024-02-29 10:29:20
# Login frequency:  2
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user676
# Login timestamps:
# 2024-02-29 10:30:05
# 2024-02-29 10:31:10
# Login frequency:  2
#
# Username: user777
# Login timestamps:
# 2024-02-29 10:32:25
# 2024-02-29 10:32:40
# Login frequency:  2
#
# Username: user878
# Login timestamps:
# 2024-02-29 10:33:55
# 2024-02-29 10:34:45
# Login frequency:  2
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user979
# Login timestamps:
# 2024-02-29 10:35:30
# 2024-02-29 10:36:20
# Login frequency:  2
#   Failed Uploads: ['presentation.pptx']
#   Reminder to user: Please upload the file 'presentation.pptx' again.
#
# Username: user080
# Login timestamps:
# 2024-02-29 10:37:15
# 2024-02-29 10:37:30
# Login frequency:  2
#
# Username: user181
# Login timestamps:
# 2024-02-29 10:38:45
# 2024-02-29 10:39:30
# Login frequency:  2
#
# Username: user282
# Login timestamps:
# 2024-02-29 10:40:00
# 2024-02-29 10:41:20
# Login frequency:  2
#   Disk space warnings: Disk space critically low
#   Please increase storage space for this user.
#
# Username: user383
# Login timestamps:
# 2024-02-29 10:42:05
# 2024-02-29 10:43:10
# Login frequency:  2
#   Connection Reset by Peer: 1
#   Potential network connectivity issues or server instability
#
# Username: user484
# Login timestamps:
# 2024-02-29 10:44:25
# 2024-02-29 10:44:40
# Login frequency:  2
#
# Username: user585
# Login timestamps:
# 2024-02-29 10:45:55
# 2024-02-29 10:46:45
# Login frequency:  2
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user686
# Login timestamps:
# 2024-02-29 10:47:30
# 2024-02-29 10:48:20
# Login frequency:  2
#   Failed Uploads: ['data.csv']
#   Reminder to user: Please upload the file 'data.csv' again.
#
# Username: user787
# Login timestamps:
# 2024-02-29 10:49:15
# 2024-02-29 10:49:45
# Login frequency:  2
#
# Username: user888
# Login timestamps:
# 2024-02-29 10:50:30
# 2024-02-29 10:51:10
# Login frequency:  2
#   Invalid authentication token errors: Invalid authentication token
#   This user may have experienced difficulties logging in. This could indicate a security breach.
#
# Username: user989
# Login timestamps:
# 2024-02-29 10:52:00
# 2024-02-29 10:53:20
# Login frequency:  2
#   Disk space warnings: Disk space low
#   Please increase storage space for this user.
#
# Username: user090
# Login timestamps:
# 2024-02-29 10:54:05
# 2024-02-29 10:55:10
# Login frequency:  2
#
# Username: user191
# Login timestamps:
# 2024-02-29 10:56:25
# 2024-02-29 10:56:40
# Login frequency:  2
#
# Username: user292
# Login timestamps:
# 2024-02-29 10:57:55
# 2024-02-29 10:58:45
# Login frequency:  2
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user393
# Login timestamps:
# 2024-02-29 10:59:30
# 2024-02-29 11:00:20
# Login frequency:  2
#   Failed Uploads: ['image.png']
#   Reminder to user: Please upload the file 'image.png' again.
#
# Username: user494
# Login timestamps:
# 2024-02-29 11:01:15
# 2024-02-29 11:01:45
# Login frequency:  2
#
# Username: user595
# Login timestamps:
# 2024-02-29 11:02:30
# 2024-02-29 11:03:10
# Login frequency:  2
#
# Username: user696
# Login timestamps:
# 2024-02-29 11:04:00
# 2024-02-29 11:05:20
# Login frequency:  2
#   Disk space warnings: Disk space critically low
#   Please increase storage space for this user.
#
# Username: user797
# Login timestamps:
# 2024-02-29 11:06:05
# 2024-02-29 11:07:10
# Login frequency:  2
#   Connection Reset by Peer: 1
#   Potential network connectivity issues or server instability
#
# Username: user898
# Login timestamps:
# 2024-02-29 11:08:25
# 2024-02-29 11:08:40
# Login frequency:  2
#
# Username: user999
# Login timestamps:
# 2024-02-29 11:09:55
# 2024-02-29 11:10:45
# Login frequency:  2
#   Internal Server Errors: 1
#   Database connection failed: database service is down
#
# Username: user000
# Login timestamps:
# 2024-02-29 11:11:30
# 2024-02-29 11:12:20
# Login frequency:  2
#   Failed Uploads: ['report.docx']
#   Reminder to user: Please upload the file 'report.docx' again.
#
# Usernames with Internal Server Errors:
# user101
# user808
# user515
# user222
# user929
# user636
# user343
# user050
# user757
# user464
# user171
# user878
# user585
# user292
# user999
# user606
# user313
# user020
# user727
# user434
#
# Usernames with Connection Reset by Peer:
# user606
# user020
# user434
# user848
# user262
# user383
# user797
# user818
# user232
#
# Average Error-Debug Time: 0:04:07.640187
